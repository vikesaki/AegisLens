# %%
# --- IMPORTS ---
import cv2
from ultralytics import YOLO
import easyocr
import numpy as np
import re

# %%
# --- INITIALIZATION ---

# Load the YOLO model
model = YOLO('35epoch.pt')

# Initialize EasyOCR Reader
reader = easyocr.Reader(['en'], gpu=True) # Use gpu=False if there is no CUDA-enabled GPU

# Open the video file
video_path = 'test.MOV'
cap = cv2.VideoCapture(video_path)

# %%
# --- CONFIGURATION FOR LABELS ---
CLASS_CONFIG = {
    3: {"label": "Plate", "color": (0, 255, 0)},      # for LicensePlate (ID: 3)
    2: {"label": "Expires", "color": (255, 165, 0)}   # for ExpiredDate (ID: 2)
}

# %%
# --- VIDEO WRITER SETUP ---
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
output_path = 'final_output_video_validated.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# %%
# --- VIDEO PROCESSING LOOP ---

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame, stream=True)

    for result in results:
        boxes = result.boxes
        for box in boxes:
            class_id = int(box.cls[0])

            if class_id in CLASS_CONFIG:
                config = CLASS_CONFIG[class_id]
                label_prefix = config["label"]
                color = config["color"]
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cropped_region = frame[y1:y2, x1:x2]
                
                ocr_text = "..." # Default text

                try:
                    ocr_results = reader.readtext(cropped_region, detail=0, paragraph=False)
                    raw_text = "".join(ocr_results).upper().replace(" ", "")

                    # --- LOGIC FOR DIFFERENT LABELS ---
                    if class_id == 3: # LicensePlate
                        ocr_text = raw_text if raw_text else "..."

                    elif class_id == 2: # ExpiredDate
                        # <<< NEW: VALIDATE DATE FORMAT (MM.YY) >>>
                        if re.match(r"^\d{2}\.\d{2}$", raw_text):
                            ocr_text = raw_text # Format is correct
                        else:
                            ocr_text = "INVALID" # Format is incorrect
                        # <<< END NEW SECTION >>>

                except Exception as e:
                    ocr_text = "ERROR"

                display_text = f"{label_prefix}: {ocr_text}"

                # Draw the bounding box and the recognized text
                cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
                (text_width, text_height), _ = cv2.getTextSize(display_text, cv2.FONT_HERSHEY_SIMPLEX, 0.7, 2)
                cv2.rectangle(frame, (x1, y1 - text_height - 10), (x1 + text_width, y1 - 5), color, -1)
                cv2.putText(frame, display_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 0), 2)

    # Write the frame and display it
    out.write(frame)
    # cv2.imshow('License Plate Recognition', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# --- CLEAN UP ---
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Car, 1 LicensePlate, 94.8ms
# Speed: 7.9ms preprocess, 94.8ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 47.3ms
# Speed: 2.0ms preprocess, 47.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# /opt/anaconda3/envs/h8_env/lib/python3.9/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 0: 384x640 1 Car, 1 LicensePlate, 39.8ms
# Speed: 2.8ms preprocess, 39.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 52.2ms
# Speed: 26.9ms preprocess, 52.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.6ms
# Speed: 1.8ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 40.1ms
# Speed: 1.8ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 39.7ms
# Speed: 1.7ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 42.8ms
# Speed: 2.7ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 38.7ms
# Speed: 1.7ms preprocess, 38.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 53.1ms
# Speed: 2.8ms preprocess, 53.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 40.8ms
# Speed: 2.6ms preprocess, 40.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 43.4ms
# Speed: 1.7ms preprocess, 43.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 39.3ms
# Speed: 1.8ms preprocess, 39.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate, 39.7ms
# Speed: 2.2ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Cars, 1 LicensePlate,
8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 38.6ms
# Speed: 1.9ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 37.5ms
# Speed: 1.7ms preprocess, 37.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 38.3ms
# Speed: 1.7ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 45.9ms
# Speed: 2.1ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 35.0ms
# Speed: 1.6ms preprocess, 35.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 38.4ms
# Speed: 1.8ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 35.6ms
# Speed: 1.7ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 39.2ms
# Speed: 1.8ms preprocess, 39.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 39.5ms
# Speed: 1.6ms preprocess, 39.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 38.9ms
# Speed: 1.9ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 39.9ms
# Speed: 1.7ms preprocess, 39.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 38.8ms
# Speed: 1.8ms preprocess, 38.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 40.0ms
# Speed: 1.8ms preprocess, 40.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 LicensePlate, 76.2ms
# Speed: 3.4ms preprocess, 76.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 68.6ms
# Speed: 2.5ms preprocess, 68.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 42.1ms
# Speed: 2.8ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 43.2ms
# Speed: 2.3ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 63.8ms
# Speed: 5.0ms preprocess, 63.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 39.3ms
# Speed: 1.8ms preprocess, 39.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 39.3ms
# Speed: 1.5ms preprocess, 39.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 40.1ms
# Speed: 2.1ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 46.1ms
# Speed: 1.7ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 39.2ms
# Speed: 1.7ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 37.4ms
# Speed: 1.9ms preprocess, 37.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 39.5ms
# Speed: 3.1ms preprocess, 39.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 39.5ms
# Speed: 2.5ms preprocess, 39.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.6ms
# Speed: 1.7ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 36.2ms
# Speed: 1.7ms preprocess, 36.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 39.4ms
# Speed: 1.9ms preprocess, 39.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 36.5ms
# Speed: 2.5ms preprocess, 36.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.4ms
# Speed: 3.1ms preprocess, 38.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 35.7ms
# Speed: 1.8ms preprocess, 35.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.0ms
# Speed: 2.3ms preprocess, 38.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 39.1ms
# Speed: 1.7ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.3ms
# Speed: 1.8ms preprocess, 38.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.5ms
# Speed: 1.6ms preprocess, 38.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.6ms
# Speed: 1.6ms preprocess, 38.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 41.6ms
# Speed: 2.1ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 41.0ms
# Speed: 1.9ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 41.1ms
# Speed: 1.7ms preprocess, 41.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.9ms
# Speed: 1.6ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 39.0ms
# Speed: 1.7ms preprocess, 39.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.9ms
# Speed: 1.8ms preprocess, 38.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 38.6ms
# Speed: 2.0ms preprocess, 38.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 1 LicensePlate, 39.0ms
# Speed: 1.8ms preprocess, 39.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 38.4ms
# Speed: 1.6ms preprocess, 38.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 46.5ms
# Speed: 2.2ms preprocess, 46.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Bus, 1 Car, 1 LicensePlate, 46.4ms
# Speed: 2.0ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 2 Motorcycles, 45.5ms
# Speed: 1.9ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 44.6ms
# Speed: 2.3ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 50.9ms
# Speed: 2.2ms preprocess, 50.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 44.4ms
# Speed: 1.8ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 43.9ms
# Speed: 3.2ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 48.8ms
# Speed: 1.9ms preprocess, 48.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 45.8ms
# Speed: 2.3ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 44.8ms
# Speed: 1.5ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.2ms
# Speed: 1.7ms preprocess, 45.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.9ms preprocess, 45.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.3ms
# Speed: 2.3ms preprocess, 52.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 43.7ms
# Speed: 1.8ms preprocess, 43.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 43.2ms
# Speed: 2.0ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 46.8ms
# Speed: 1.7ms preprocess, 46.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 43.7ms
# Speed: 1.7ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Motorcycles, 43.2ms
# Speed: 2.3ms preprocess, 43.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 43.7ms
# Speed: 1.8ms preprocess, 43.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Motorcycle, 50.0ms
# Speed: 1.7ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Motorcycles, 45.5ms
# Speed: 1.7ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 45.8ms
# Speed: 1.7ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 39.3ms
# Speed: 2.5ms preprocess, 39.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.2ms
# Speed: 1.7ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 75.9ms
# Speed: 1.7ms preprocess, 75.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.6ms
# Speed: 2.4ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.0ms
# Speed: 1.7ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.8ms
# Speed: 2.2ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.8ms
# Speed: 2.2ms preprocess, 45.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.6ms
# Speed: 1.6ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 47.2ms
# Speed: 1.6ms preprocess, 47.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.3ms
# Speed: 2.4ms preprocess, 44.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.9ms
# Speed: 1.6ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.5ms
# Speed: 1.8ms preprocess, 42.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 50.1ms
# Speed: 1.5ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.0ms
# Speed: 1.8ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.5ms
# Speed: 2.2ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.9ms
# Speed: 1.7ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.5ms
# Speed: 1.9ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.6ms
# Speed: 1.6ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.3ms
# Speed: 1.7ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.8ms
# Speed: 2.1ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 52.3ms
# Speed: 3.0ms preprocess, 52.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.2ms
# Speed: 2.4ms preprocess, 45.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.0ms
# Speed: 1.8ms preprocess, 46.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.2ms
# Speed: 1.6ms preprocess, 46.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 50.2ms
# Speed: 1.5ms preprocess, 50.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.4ms
# Speed: 1.6ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.3ms
# Speed: 1.8ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.8ms
# Speed: 2.3ms preprocess, 41.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.3ms
# Speed: 1.6ms preprocess, 45.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.9ms
# Speed: 2.2ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.9ms
# Speed: 1.7ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.1ms
# Speed: 1.9ms preprocess, 42.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.9ms
# Speed: 2.4ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 72.1ms
# Speed: 1.7ms preprocess, 72.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.6ms
# Speed: 1.6ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.0ms
# Speed: 2.3ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 40.4ms
# Speed: 1.7ms preprocess, 40.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.6ms
# Speed: 2.1ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.2ms
# Speed: 1.6ms preprocess, 44.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.5ms
# Speed: 2.1ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.3ms
# Speed: 2.3ms preprocess, 41.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.0ms
# Speed: 1.5ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.0ms
# Speed: 2.3ms preprocess, 45.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.6ms
# Speed: 2.2ms preprocess, 43.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.0ms
# Speed: 2.1ms preprocess, 46.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.3ms
# Speed: 3.3ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.9ms
# Speed: 2.1ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.7ms
# Speed: 1.7ms preprocess, 45.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.1ms
# Speed: 1.7ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.4ms
# Speed: 2.1ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 62.0ms
# Speed: 1.7ms preprocess, 62.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.1ms
# Speed: 2.3ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 47.0ms
# Speed: 1.9ms preprocess, 47.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.9ms
# Speed: 2.4ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.0ms
# Speed: 2.2ms preprocess, 42.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.0ms
# Speed: 2.4ms preprocess, 44.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 75.7ms
# Speed: 2.2ms preprocess, 75.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.3ms
# Speed: 2.0ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.5ms
# Speed: 2.1ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.9ms
# Speed: 1.6ms preprocess, 42.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.4ms
# Speed: 2.2ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.9ms
# Speed: 2.4ms preprocess, 41.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.6ms
# Speed: 2.2ms preprocess, 42.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.9ms
# Speed: 1.7ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 49.1ms
# Speed: 1.6ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.4ms
# Speed: 2.0ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.8ms
# Speed: 1.7ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 42.5ms
# Speed: 1.8ms preprocess, 42.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 40.9ms
# Speed: 1.8ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 49.0ms
# Speed: 1.8ms preprocess, 49.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.1ms
# Speed: 1.8ms preprocess, 41.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 50.1ms
# Speed: 1.6ms preprocess, 50.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.8ms
# Speed: 1.7ms preprocess, 43.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.9ms
# Speed: 1.9ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.5ms
# Speed: 2.4ms preprocess, 45.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.3ms
# Speed: 1.8ms preprocess, 43.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 47.8ms
# Speed: 1.7ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.7ms
# Speed: 1.7ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.1ms
# Speed: 1.8ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 73.4ms
# Speed: 1.6ms preprocess, 73.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 46.1ms
# Speed: 2.2ms preprocess, 46.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 53.0ms
# Speed: 2.2ms preprocess, 53.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 50.6ms
# Speed: 1.6ms preprocess, 50.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.9ms
# Speed: 1.6ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 43.0ms
# Speed: 1.7ms preprocess, 43.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 45.6ms
# Speed: 2.5ms preprocess, 45.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Car, 41.6ms
# Speed: 2.2ms preprocess, 41.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)

# %%
print(f"Processed video saved to: {output_path}")
# Out:
# Processed video saved to: final_output_video_validated.mp4
